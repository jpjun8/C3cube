# %%
import matplotlib.pyplot as plt
import numpy as np

from pathlib import Path

# %%
path_noto = Path('./fonts/NotoSansCJKkr-Regular.otf')

plt.plot(range(10))
plt.title('Random Stuff 랜덤 스터프', font=path_noto)
plt.show()
