# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from scipy import stats
from matplotlib import cm

plt.rc('font', family='Malgun Gothic')
plt.style.use('ggplot')
plt.rcParams['axes.facecolor'] = '#f5f5f5'
warnings.filterwarnings('ignore')

colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']

# %%
df = pd.read_csv("./prices.csv")
# df.head()
df2 = df.drop(columns=["통계표", "단위", "변환"])
df2.head()
# Out:
#             계정항목     가중치  2020/11  2020/12  2021/01  2021/02  2021/03  \
# 0            총지수  1000.0   100.09   100.33   101.04   101.58   101.84
# 1    식료품 및 비주류음료   154.5   101.24   101.51   103.39   105.69   105.84
# 2            식료품   144.2   101.25   101.60   103.55   106.05   106.16
# 3         빵 및 곡물    24.0   102.18   102.76   103.51   103.53   105.77
# 4              쌀     5.5   108.33   109.17   109.54   109.84   110.19
#
#    2021/04  2021/05  2021/06  ...  2022/02  2022/03  2022/04  2022/05  \
# 0   101.98   102.05   102.05  ...   105.30   106.06   106.85   107.56
# 1   105.35   105.16   104.56  ...   109.49   109.38   110.16   111.49
# 2   105.67   105.46   104.82  ...   109.67   109.52   110.23   111.69
# 3   105.98   106.32   106.48  ...   107.94   110.12   109.96   109.94
# 4   110.08   110.65   110.73  ...   102.87   101.90    99.94    98.23
#
#    2022/06  2022/07  2022/08  2022/09  2022/10  2022/11
# 0   108.22   108.74   108.62   108.93   109.21   109.10
# 1   111.40   113.12   114.69   116.30   114.77   112.41
# 2   111.56   113.44   115.17   116.82   115.15   112.60
# 3   109.73   110.47   110.82   110.82   112.68   114.07
# 4    96.77    95.23    92.80    90.34    91.08    96.16
#
# [5 rows x 27 columns]
